# %%
import pandas as pd

# Cargar el archivo Excel
file_path = '/Users/luis/Desktop/00. UEV/Primero/00. Proyecto Análisis de Datos UE/Entrega 5/WDIEXCEL.xlsx'
excel_data = pd.ExcelFile(file_path)

# %%
# Leer la hoja específica "DATA"
df = pd.read_excel(excel_data, sheet_name='Data')

# %%
valores_unicos= df['Indicator Name'].unique()
df_valores_unicos = pd.DataFrame(valores_unicos, columns=['Unique Indicator Names'])
# Guardar los valores únicos en un archivo Excel
excel_file_path2 = '/Users/luis/Desktop/00. UEV/Primero/00. Proyecto Análisis de Datos UE/Entrega 5/valoresUnicos.xlsx'
df_valores_unicos.to_excel(excel_file_path2, sheet_name='Unicos', index=False)

print(f"Valores únicos guardados como Excel en: {excel_file_path2}")
# Out:
# Valores únicos guardados como Excel en: /Users/luis/Desktop/00. UEV/Primero/00. Proyecto Análisis de Datos UE/Entrega 5/valoresUnicos.xlsx

# %%
indicadores_valores_unicos = [

"Employment in agriculture (% of total employment) (modeled ILO estimate)",
"Employment in industry (% of total employment) (modeled ILO estimate)"
"Employment in services (% of total employment) (modeled ILO estimate)",
]

# %%
# Lista de indicadores relevantes
indicadores_relevantes = [
    "Unemployment, total (% of total labor force) (modeled ILO estimate)",
    #"Unemployment, total (% of total labor force) (national estimate)",
    "Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)",
    #"Unemployment, youth total (% of total labor force ages 15-24) (national estimate)",
    "Unemployment with advanced education (% of total labor force with advanced education)",
    "Unemployment with basic education (% of total labor force with basic education)",
    "Unemployment with intermediate education (% of total labor force with intermediate education)",
    "Labor force participation rate, total (% of total population ages 15+)",
    "Labor force participation rate, female (% of female population ages 15+)",
    "Labor force participation rate, male (% of male population ages 15+)",
    "Labor force, total",
    "Labor force, female (% of total labor force)",
    "Labor force, male (% of total labor force)",
    "Employment in agriculture (% of total employment) (modeled ILO estimate)",
    "Employment in industry (% of total employment) (modeled ILO estimate)",
    "Employment in services (% of total employment) (modeled ILO estimate)",
    "Employment to population ratio, 15+, total (%)",
    "Employment to population ratio, ages 15-24, total (%)",
    "GDP growth (annual %)",
    "GDP per capita (current US$)",
    "GDP per capita growth (annual %)",
    #"Poverty headcount ratio at national poverty lines (% of population)",
    #"School enrollment, primary (% net)",
    #"School enrollment, secondary (% net)",
    #"School enrollment, tertiary (% gross)",
    #"Educational attainment, at least completed primary, population 25+ years, total (%)",
    #"Educational attainment, at least completed secondary, population 25+ years, total (%)",
    #"Educational attainment, at least completed tertiary, population 25+ years, total (%)",
    #"Life expectancy at birth, total (years)",
    #"Poverty gap at $1.90 a day (PPP) (% of population)",
    "Population, total",
    "Population, female",
    "Population, female (% of total population)",
    "Population, male",
    "Population, male (% of total population)",
    "Compulsory education, duration (years)",
    "Government expenditure on education, total (% of GDP)",
    "Government expenditure on education, total (% of government expenditure)"

]

# Filtrar el DataFrame para incluir solo los indicadores relevantes
df_relevant = df[df['Indicator Name'].isin(indicadores_relevantes)]

# Mostrar las primeras filas del DataFrame filtrado
df_relevant.head()
# Out:
#                     Country Name Country Code  \
# 223  Africa Eastern and Southern          AFE
# 366  Africa Eastern and Southern          AFE
# 369  Africa Eastern and Southern          AFE
# 372  Africa Eastern and Southern          AFE
# 478  Africa Eastern and Southern          AFE
#
#                                         Indicator Name     Indicator Code  \
# 223             Compulsory education, duration (years)        SE.COM.DURS
# 366  Employment in agriculture (% of total employme...     SL.AGR.EMPL.ZS
# 369  Employment in industry (% of total employment)...     SL.IND.EMPL.ZS
# 372  Employment in services (% of total employment)...     SL.SRV.EMPL.ZS
# 478                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
#
#      1960      1961      1962      1963      1964      1965  ...       2014  \
# 223   NaN       NaN       NaN       NaN       NaN       NaN  ...   7.000000
# 366   NaN       NaN       NaN       NaN       NaN       NaN  ...  58.827249
# ...

# %%
valores_unicos_df_relevant2022= df_relevant['Indicator Name'].unique()
valores_unicos_df_relevant2022
# Out:
# array(['Compulsory education, duration (years)',
#        'Employment in agriculture (% of total employment) (modeled ILO estimate)',
#        'Employment in industry (% of total employment) (modeled ILO estimate)',
#        'Employment in services (% of total employment) (modeled ILO estimate)',
#        'GDP growth (annual %)', 'GDP per capita (current US$)',
#        'GDP per capita growth (annual %)',
#        'Government expenditure on education, total (% of GDP)',
#        'Government expenditure on education, total (% of government expenditure)',
#        'Labor force, female (% of total labor force)',
#        'Labor force, total', 'Population, female',
#        'Population, female (% of total population)', 'Population, male',
#        'Population, male (% of total population)', 'Population, total',
#        'Unemployment with advanced education (% of total labor force with advanced education)',
# ...

# %%
df_relevant.values
# Out:
# array([['Africa Eastern and Southern', 'AFE',
#         'Compulsory education, duration (years)', ..., 7.0, 7.0, nan],
#        ['Africa Eastern and Southern', 'AFE',
#         'Employment in agriculture (% of total employment) (modeled ILO estimate)',
#         ..., 56.37662059383139, 55.75077488269868, nan],
#        ['Africa Eastern and Southern', 'AFE',
#         'Employment in industry (% of total employment) (modeled ILO estimate)',
#         ..., 9.94300492327448, 10.111156355463933, nan],
#        ...,
#        ['Zimbabwe', 'ZWE',
#         'Unemployment with intermediate education (% of total labor force with intermediate education)',
#         ..., 11.589, nan, nan],
#        ['Zimbabwe', 'ZWE',
#         'Unemployment, total (% of total labor force) (modeled ILO estimate)',
#         ..., 9.54, 9.256, 9.116],
#        ['Zimbabwe', 'ZWE',
#         'Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)',
# ...

# %%
df_relevant.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023'],
#       dtype='object')

# %%
df_relevant = df_relevant.rename(columns={'1960': 'Año 1960'})
df_relevant = df_relevant.rename(columns={'2022': 'Año 2022'})
df_relevant = df_relevant.rename(columns={'2023': 'Año 2023'})
df_relevant = df_relevant.rename(columns={'2021': 'Año 2021'})

# %%
df_relevant2022 = df_relevant[['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code','Año 2022']]

# %%
df_relevant2022
# Out:
#                        Country Name Country Code  \
# 223     Africa Eastern and Southern          AFE
# 366     Africa Eastern and Southern          AFE
# 369     Africa Eastern and Southern          AFE
# 372     Africa Eastern and Southern          AFE
# 478     Africa Eastern and Southern          AFE
# ...                             ...          ...
# 396811                     Zimbabwe          ZWE
# 396814                     Zimbabwe          ZWE
# 396817                     Zimbabwe          ZWE
# 396824                     Zimbabwe          ZWE
# 396830                     Zimbabwe          ZWE
#
#                                            Indicator Name     Indicator Code  \
# 223                Compulsory education, duration (years)        SE.COM.DURS
# 366     Employment in agriculture (% of total employme...     SL.AGR.EMPL.ZS
# 369     Employment in industry (% of total employment)...     SL.IND.EMPL.ZS
# ...

# %%
valores_unicos_df_relevant2022= df_relevant2022['Indicator Name'].unique()
valores_unicos_df_relevant2022
# Out:
# array(['Compulsory education, duration (years)',
#        'Employment in agriculture (% of total employment) (modeled ILO estimate)',
#        'Employment in industry (% of total employment) (modeled ILO estimate)',
#        'Employment in services (% of total employment) (modeled ILO estimate)',
#        'GDP growth (annual %)', 'GDP per capita (current US$)',
#        'GDP per capita growth (annual %)',
#        'Government expenditure on education, total (% of GDP)',
#        'Government expenditure on education, total (% of government expenditure)',
#        'Labor force, female (% of total labor force)',
#        'Labor force, total', 'Population, female',
#        'Population, female (% of total population)', 'Population, male',
#        'Population, male (% of total population)', 'Population, total',
#        'Unemployment with advanced education (% of total labor force with advanced education)',
# ...

# %%
xls_file_path = '/Users/luis/Desktop/00. UEV/Primero/00. Proyecto Análisis de Datos UE/Entrega 5/LimpiosBankWorld.xlsx'
df_relevant2022.to_excel(xls_file_path, sheet_name='Seleccionados', index=False)

# %%
# Pivotar el DataFrame para que los indicadores sean filas
df_pivotado = df_relevant2022.pivot_table(
    index=['Country Name', 'Country Code'],
    columns='Indicator Name',
    values='Año 2022'
).reset_index()

# Mostrar las primeras filas del DataFrame pivotado
df_pivotado.head()
# Out:
# Indicator Name                 Country Name Country Code  \
# 0                               Afghanistan          AFG
# 1               Africa Eastern and Southern          AFE
# 2                Africa Western and Central          AFW
# 3                                   Albania          ALB
# 4                                   Algeria          DZA
#
# Indicator Name  Compulsory education, duration (years)  \
# 0                                                  9.0
# 1                                                  7.0
# 2                                                  9.0
# 3                                                  9.0
# 4                                                 10.0
#
# Indicator Name  Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# 0                                                       46.589070
# 1                                                       55.750775
# ...

# %%
# Guardar el DataFrame pivotado en un archivo CSV
csv_file_path = '/Users/luis/Desktop/00. UEV/Primero/00. Proyecto Análisis de Datos UE/Entrega 5/df_pivotado_new.csv'
df_pivotado.to_csv(csv_file_path, index=False)

# Guardar el DataFrame pivotado en un archivo Excel
excel_file_path1 = '/Users/luis/Desktop/00. UEV/Primero/00. Proyecto Análisis de Datos UE/Entrega 5/df_pivotado_new.xlsx'

df_pivotado.to_excel(excel_file_path1, sheet_name='Pivotado', index=False)

# %%
df_pivotado.head(30)
# Out:
# Indicator Name                 Country Name Country Code  \
# 0                               Afghanistan          AFG
# 1               Africa Eastern and Southern          AFE
# 2                Africa Western and Central          AFW
# 3                                   Albania          ALB
# 4                                   Algeria          DZA
# 5                            American Samoa          ASM
# 6                                   Andorra          AND
# 7                                    Angola          AGO
# 8                       Antigua and Barbuda          ATG
# 9                                Arab World          ARB
# 10                                Argentina          ARG
# 11                                  Armenia          ARM
# 12                                    Aruba          ABW
# 13                                Australia          AUS
# 14                                  Austria          AUT
# ...
